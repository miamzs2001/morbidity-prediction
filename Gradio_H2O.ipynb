# %%
# !pip install gradio
# !pip install auto-sklearn
# !pip install -U numpy
# !pip install h2o
#Restart runtime after running this cell

# %%
import gradio as gr
import pickle
import autosklearn
from autosklearn.classification import AutoSklearnClassifier
import pandas as pd
import h2o

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         5 hours 38 mins
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.40.0.4
# H2O_cluster_version_age:    1 month and 20 days
# H2O_cluster_name:           H2O_from_python_unknownUser_jh49yc
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.165 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.10.12 final
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model = h2o.load_model('/content/drive/MyDrive/Colab Notebooks/StackedEnsemble_BestOfFamily_4_AutoML_1_20230614_40851')

# %%
def my_model(f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17,f18,f19,f20,f21,f22,f23,f24,f25,f26,f27,f28,f29,f30,f31,f32,f33,f34,f35,f36,f37,f38,f39,f40,f41,f42,f43,f44,f45,f46,f47,f48,f49,f50,f51,f52,f53,f54,f55,f56,f57,f58,f59,f60,f61,f62,f63,f64,f65,f66,f67,f68,f69,f70,f71,f72,f73,f74,f75,f76,f77,f78,f79,f80,f81,f82,f83,f84,f85,f86,f87):
    #inputs = [f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17,f18,f19,f20,f21,f22,f23,f24,f25,f26,f27,f28,f29,f30,f31,f32,f33,f34,f35,f36,f37,f38,f39,f40,f41,f42,f43,f44,f45,f46,f47,f48,f49,f50,f51,f52,f53,f54,f55,f56,f57,f58,f59,f60,f61,f62,f63,f64,f65,f66,f67,f68,f69,f70,f71,f72,f73,f74,f75,f76,f77,f78,f79,f80,f81,f82,f83,f84,f85,f86]

    inputs = {
      "MaternalDM": f1,
      "MaternalHT": f2,
      "MaternalEclamp": f3,
      "MaternalChorAm": f4,
      "MaternalAnemia": f5,
      "MaternalAbPlacenta": f6,
      "MaternalBleedPlacenta": f7,
      "MaternalCoredProlap": f8,
      "MaternalObesity": f9,
      "BirthDrugAtMagSulfate": f10,
      "BirthDrugIAntibiotic": f11,
      "MotherAge": f12,
      "MotherG": f13,
      "MotherP": f14,
      "MotherA": f15,
      "MaternalOtherIllness": f16,
      "BirthDrugAtSteroidCat": f17,
      "BirthWt": f18,
      "BirthGestation": f19,
      "BirthMultiplicity": f20,
      "Vacuum": f21,
      "Forcep": f22,
      "Apgar1Min": f23,
      "Apgar5Min": f24,
      "InitResus_O2": f25,
      "InitResus_CPAP": f26,
      "InitResus_BMV": f27,
      "InitResus_ETV": f28,
      "InitResus_CC": f29,
      "InitResus_Adren": f30,
      "BirthAdmissionTemp": f31,
      "RespSpt_CPAPDur": f32,
      "RespSpt_HFNCDur": f33,
      "RespSpt_ConvVentDur": f34,
      "RespSpt_HFOVDur": f35,
      "RespSpt_NitrixOxideDur": f36,
      "Surfactant": f37,
      "OtherDiagRespPH": f38,
      "OtherDiagRespCongenitalPneu": f39,
      "OtherDiagResp0socomialPneu": f40,
      "OtherDiagRespCommunityAcqPneu": f41,
      "OtherDiagRespTTN": f42,
      "OtherDiagRespPI": f43,
      "DiagRDS": f44,
      "DiagPneumothoraxDev": f45,
      "OtherDiagCardio": f46,
      "CVS_HeartFailure": f47,
      "DiagPDA": f48,
      "DiagPDAEchoDone": f49,
      "DiagPDAPharmaClosure": f50,
      "DiagPDAPharmaClosure_Indomethacin": f51,
      "DiagPDAPharmaClosure_Ibuprofen": f52,
      "DiagPDAPharmaClosure_Paracetamol": f53,
      "DiagPDALigation": f54,
      "DiagNEC": f55,
      "DiagNEC_SurgicalRx": f56,
      "DiagNEC_Present": f57,
      "DiagROPStage": f58,
      "DiagROPStage_APROP": f59,
      "DiahROPDisease": f60,
      "DiagROPLeserTy": f61,
      "DiagROPAntiVEGF": f62,
      "DiagROPVitrectomy": f63,
      "DiagROPPresent": f64,
      "DiagIVHGrade": f65,
      "DiagIVHVPShunt": f66,
      "DiagCysticPVL": f67,
      "DiagCVL_Duration": f68,
      "DiagCLABSI": f69,
      "DiagInf": f70,
      "DiagInf1stEplConfimSepsis_LessEqual72Hrs": f71,
      "DiagConfSepGpB_LessEqual72Hrs": f72,
      "DiagInf1stEplConfirmSepsis_More72Hrs": f73,
      "DiagConfSepGpB_More72Hrs": f74,
      "DiagConfSepStaphy_More72Hrs": f75,
      "DiagHIE": f76,
      "f77": f77,
      "f78": f78,
      "f79": f79,
      "f80": f80,
      "f81": f81,
      "f82": f82,
      "f83": f83,
      "f84": f84,
      "f85": f85,
      "f86": f86,
      "f87": f87
    }

    # Convert inputs into pandas dataframe
    df = pd.DataFrame(inputs, index=[0])

    #One-hot encode categorical features
    df = pd.concat([df,pd.get_dummies(df['f77'], prefix='CSUrgency')],axis=1)
    df = df.drop(['f77'],axis=1)
    df = pd.concat([df,pd.get_dummies(df['f78'], prefix='DiagPneumothoraxDev')],axis=1)
    df = df.drop(['f78'],axis=1)
    df = pd.concat([df,pd.get_dummies(df['f79'], prefix='BirthSex')],axis=1)
    df = df.drop(['f79'],axis=1)
    df = pd.concat([df,pd.get_dummies(df['f80'], prefix='BirthBabryStatus')],axis=1)
    df = df.drop(['f80'],axis=1)
    df = pd.concat([df,pd.get_dummies(df['f81'], prefix='BirthFinalModeDeliver')],axis=1)
    df = df.drop(['f81'],axis=1)
    df = pd.concat([df,pd.get_dummies(df['f82'], prefix='BirthFinalModeDeliverCd')],axis=1)
    df = df.drop(['f82'],axis=1)
    df = pd.concat([df,pd.get_dummies(df['f83'], prefix='BirthGrowthStatus')],axis=1)
    df = df.drop(['f83'],axis=1)
    df = pd.concat([df,pd.get_dummies(df['f84'], prefix='BirthPlaceBirth_v5')],axis=1)
    df = df.drop(['f84'],axis=1)
    df = pd.concat([df,pd.get_dummies(df['f85'], prefix='PlasticWrapAtBirth')],axis=1)
    df = df.drop(['f85'],axis=1)
    df = pd.concat([df,pd.get_dummies(df['f86'], prefix='PtRaceID')],axis=1)
    df = df.drop(['f86'],axis=1)
    df = pd.concat([df,pd.get_dummies(df['f87'], prefix='SurfactantDuration')],axis=1)
    df = df.drop(['f87'],axis=1)


    # Convert pandas dataframe into H2O Frame
    input_frame = h2o.H2OFrame(df)

    # Make a prediction using the saved model
    prediction = model.predict(input_frame)

    # Convert the prediction to a pandas DataFrame and return the result
    if prediction.as_data_frame().values[0][0]==0:
      return Alive
    else if prediction.as_data_frame().values[0][0]==1:
      return Dead

# %%
f1 = gr.inputs.Radio(choices = [0,1], label="MaternalDM")
f2 = gr.inputs.Radio(choices = [0,1], label="MaternalHT")
f3 = gr.inputs.Radio(choices = [0,1], label="MaternalEclamp")
f4 = gr.inputs.Radio(choices = [0,1], label="MaternalChorAm")
f5 = gr.inputs.Radio(choices = [0,1], label="MaternalAnemia")
f6 = gr.inputs.Radio(choices = [0,1], label="MaternalAbPlacenta")
f7 = gr.inputs.Radio(choices = [0,1], label="MaternalBleedPlacenta")
f8 = gr.inputs.Radio(choices = [0,1], label="MaternalCoredProlap")
f9 = gr.inputs.Radio(choices = [0,1], label="MaternalObesity")
f10 = gr.inputs.Radio(choices = [0,1], label="BirthDrugAtMagSulfate")
f11 = gr.inputs.Radio(choices = [0,1], label="BirthDrugIAntibiotic")
f12 = gr.inputs.Number(label="MotherAge") #Cond: >0
f13 = gr.inputs.Number(label="MotherG") #Cond: >0
f14 = gr.inputs.Number(label="MotherP") #Cond: >=0
f15 = gr.inputs.Number(label="MotherA") #Cond: >=0
f16 = gr.inputs.Radio(choices = [0,1], label="MaternalOtherIllness")
f17 = gr.inputs.Dropdown(choices=[0, 1, 2], label=f"BirthDrugAtSteroidCat")
f18 = gr.inputs.Number(label=f"BirthWt (g)")
f19 = gr.inputs.Number(label=f"BirthGestation") #Cond: >=0
f20 = gr.inputs.Number(label=f"BirthMultiplicity") #Cond: >0
f21 = gr.inputs.Radio(choices = [0,1], label="Vacuum")
f22 = gr.inputs.Radio(choices = [0,1], label="Forcep")
f23 = gr.inputs.Dropdown(choices=list(range(11)), label=f"Apgar1Min")
f24 = gr.inputs.Dropdown(choices=list(range(11)), label=f"Apgar5Min")
f25 = gr.inputs.Radio(choices = [0,1], label="InitResus_O2")
f26 = gr.inputs.Radio(choices = [0,1], label="InitResus_CPAP")
f27 = gr.inputs.Radio(choices = [0,1], label="InitResus_BMV")
f28 = gr.inputs.Radio(choices = [0,1], label="InitResus_ETV")
f29 = gr.inputs.Radio(choices = [0,1], label="InitResus_CC")
f30 = gr.inputs.Radio(choices = [0,1], label="InitResus_Adren")
f31 = gr.inputs.Number(label=f"BirthAdmissionTemp") #Cond: >0
f32 = gr.inputs.Number(label=f"RespSpt_CPAPDur") #Cond: >=0
f33 = gr.inputs.Number(label=f"RespSpt_HFNCDur") #Cond: >=0
f34 = gr.inputs.Number(label=f"RespSpt_ConvVentDur") #Cond: >=0
f35 = gr.inputs.Number(label=f"RespSpt_HFOVDur") #Cond: >=0
f36 = gr.inputs.Number(label=f"RespSpt_NitrixOxideDur") #Cond: >=0
f37 = gr.inputs.Radio(choices = [0,1], label="Surfactant")
f38 = gr.inputs.Radio(choices = [0,1], label="OtherDiagRespPH")
f39 = gr.inputs.Radio(choices = [0,1], label="OtherDiagRespCongenitalPneu")
f40 = gr.inputs.Radio(choices = [0,1], label="OtherDiagResp0somicalPneu")
f41 = gr.inputs.Radio(choices = [0,1], label="OtherDiagRespCommunityAcqPneu")
f42 = gr.inputs.Radio(choices = [0,1], label="OtherDiagRespTTN")
f43 = gr.inputs.Radio(choices = [0,1], label="OtherDiagRespPI")
f44 = gr.inputs.Radio(choices = [0,1], label="DiagRDS")
f45 = gr.inputs.Dropdown(choices=list(range(5)), label=f"DiagPneumothoraxDev")
f46 = gr.inputs.Radio(choices = [0,1], label="OtherDiagCardio")
f47 = gr.inputs.Radio(choices = [0,1], label="CVS_HeartFailure")
f48 = gr.inputs.Radio(choices = [0,1], label="DiagPDA")
f49 = gr.inputs.Radio(choices = [0,1], label="DiagPDAEchoDone")
f50 = gr.inputs.Radio(choices = [0,1], label="DiagPDAPharmaClosure")
f51 = gr.inputs.Radio(choices = [0,1], label="DiagPDAPharmaClosure_Indomethacin")
f52 = gr.inputs.Radio(choices = [0,1], label="DiagPDAPharmaClosure_Ibuprofin")
f53 = gr.inputs.Radio(choices = [0,1], label="DiagPDAPharmaClosure_Paracetamol")
f54 = gr.inputs.Radio(choices = [0,1], label="DiagPDALigation")
f55 = gr.inputs.Radio(choices = [0,1], label="DiagNEC")
f56 = gr.inputs.Radio(choices = [0,1], label="DiagNEC_SurgicalRx")
f57 = gr.inputs.Radio(choices = [0,1], label="DiagNEC_Present")
f58 = gr.inputs.Radio(choices = [0,1], label="DiagROPStage")
f59 = gr.inputs.Radio(choices = [0,1], label="DiagROPStage_APROP")
f60 = gr.inputs.Radio(choices = [0,1], label="DiagROPDisease")
f61 = gr.inputs.Radio(choices = [0,1], label="DiagROPLaserTy")
f62 = gr.inputs.Radio(choices = [0,1], label="DiagROPAntiVEGF")
f63 = gr.inputs.Radio(choices = [0,1], label="DiagROPVitrectomy")
f64 = gr.inputs.Radio(choices = [0,1], label="DiagROPPresent")
f65 = gr.inputs.Dropdown(choices=list(range(5)), label=f"DiagIVHGrade")
f66 = gr.inputs.Radio(choices = [0,1], label="DiagIVHPShunt")
f67 = gr.inputs.Radio(choices = [0,1], label="DiagCyticPVL")
f68 = gr.inputs.Number(label=f"DiagCVL_Duration") #Cond: >=0
f69 = gr.inputs.Radio(choices = [0,1], label="DiagCLABSI")
f70 = gr.inputs.Radio(choices = [0,1], label="DiagInf")
f71 = gr.inputs.Radio(choices = [0,1], label="DiagInf1stEplConfirmSepsis_LessEqual72Hrs")
f72 = gr.inputs.Radio(choices = [0,1], label="DiagConfSepGpB_LessEqual72Hrs")
f73 = gr.inputs.Radio(choices = [0,1], label="DiagInf1stEplConfirmSepsis_More72Hrs")
f74 = gr.inputs.Radio(choices = [0,1], label="DiagConfGpB_More72Hrs")
f75 = gr.inputs.Radio(choices = [0,1], label="DiagConfSepStaphy_More72Hrs")
f76 = gr.inputs.Dropdown(choices=list(range(5)), label=f"DiagHIE")
f77 = gr.inputs.Radio(choices=["Elective", "Emergency"], label=f"CSUrgency")
f78 = gr.inputs.Radio(choices=["CMV", "CPAP", "HFV", "Spontaneous"], label=f"DiagPneumothoraxDev")
f79 = gr.inputs.Radio(choices=["Female", "Male"], label=f"BirthSex")
f80 = gr.inputs.Radio(choices=["Inborn", "Outborn"], label=f"BirthBabyStatus")
f81 = gr.inputs.Radio(choices=["Other"], label=f"BirthFinalModeDeliver")
f82 = gr.inputs.Radio(choices=["Breech", "SVD"], label=f"BirthFinalModeDeliverCd")
f83 = gr.inputs.Radio(choices=["AGA", "LGA", "SGA"], label=f"BirthGrowthStatus")
f84 = gr.inputs.Radio(choices=["Enroute/During transport", "Government hospital with specialist", "Government hospital without specialist", "Health clinic", "Home", "Others", "Private hospital", "University Hospital"], label=f"BirthPlaceBirth")
f85 = gr.inputs.Radio(choices=["0","1","woDry"],label=f"PlasticWrapAtBirth")
f86 = gr.inputs.Radio(choices=["Bumiputra Sabah","Bumiputra Sarawak","Chinese","Indian","Malay","Non-citizen","Orang Asli","Other Malaysian"],label=f"PtRaceID")
f87 = gr.inputs.Radio(choices=["1-2 hrs","<1hr",">2hrs"],label=f"SurfactantDuration")

inputs = [f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17,f18,f19,f20,f21,f22,f23,f24,f25,f26,f27,f28,f29,f30,f31,f32,f33,f34,f35,f36,f37,f38,f39,f40,f41,f42,f43,f44,f45,f46,f47,f48,f49,f50,f51,f52,f53,f54,f55,f56,f57,f58,f59,f60,f61,f62,f63,f64,f65,f66,f67,f68,f69,f70,f71,f72,f73,f74,f75,f76,f77,f78,f79,f80,f81,f82,f83,f84,f85,f86,f87]

iface = gr.Interface(fn=my_model, inputs=inputs, outputs="text", title="Neonate Morbidity Prediction")
#iface.launch(debug=True)
iface.launch()
# Out:
# /usr/local/lib/python3.10/dist-packages/gradio/inputs.py:185: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/gradio/inputs.py:188: UserWarning: `optional` parameter is deprecated, and it has no effect
#   super().__init__(
# /usr/local/lib/python3.10/dist-packages/gradio/inputs.py:59: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/gradio/inputs.py:62: UserWarning: `optional` parameter is deprecated, and it has no effect
#   super().__init__(value=default, label=label, optional=optional)
# ...
